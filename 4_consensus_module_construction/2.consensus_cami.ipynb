# %% [markdown]
# Here we want to run consensus on all the methods
#
# inputs:
# 1) raw seed genes of each combination
# 2) PPI network for each tissue
# 3) list of modules in all methods

# %%
import os
import pandas as pd
from pathlib import Path
import subprocess

# %%
workdir = os.path.dirname(os.getcwd())
input_dir = Path(f"{workdir}/3_module_expansion/results_full_PPI")
ppi_dir = Path("/home/bbc8731/diseasemodulediscovery/tests/uniprot_ppi.csv")
output_dir = Path("/home/bbc8731/HSV/4_consensus_module_detection/cami_results")
output_dir.mkdir(parents=True, exist_ok=True)

# %%
for dir in input_dir.glob('*'):
    seeds_dirs = dir / 'input' / 'seeds'
    module_dir = dir / 'modules'/ 'tsv_nodes'

    for seed_path in seeds_dirs.glob('*.tsv'): # seed_path: seeds
        if seed_path.name.endswith(('.removed.tsv', '.multiqc.tsv')):
            continue

        seed_file = seed_path.name
        dir_tissue = ".".join(seed_file.split(".", 2)[:2]) 

        # ===============================
        # find matching modules 
        # ===============================

        module_paths = [
            m for m in module_dir.glob("*.tsv")
            if (dir_tissue in m.name) and ("firstneighbor" not in m.name)
        ]

        if not module_paths:
            continue

        # ===============================
        # Convert formats
        # ===============================
        if (dir.name == "CC_background_control"):
            dir_tissue = f"CC_{dir_tissue}"

        if (dir.name == "BP_background_control"):
            dir_tissue = f"BP_{dir_tissue}"

        run_dir = output_dir / dir_tissue
        run_dir.mkdir(exist_ok=True)

        # seeds: tsv -> txt , cami needs text not tsv
        seeds_txt = run_dir / "seeds.txt"
        seeds_df = pd.read_csv(seed_path, sep="\t", header=None)
        seeds_df.iloc[:, 0].to_csv(seeds_txt, index=False, header=False)
        
        # ppi: csv -> tsv 
        ppi_tsv = run_dir / "ppi.tsv"
        ppi_df = pd.read_csv(ppi_dir)
        ppi_df.to_csv(ppi_tsv, sep="\t", index=False)

        # modules: tsv -> txt
        module_args = []
        for m in module_paths:
            # file has a real header
            mod_df = pd.read_csv(m, sep="\t")
        
            # output file
            mod_out = run_dir / m.name.replace(".tsv", ".txt")
        
            # extract method name: domino
            method_name = m.stem.split(".")[2]
        
            with open(mod_out, "w") as f:
                # first line = method name
                f.write(method_name + "\n")
        
                # remaining lines = node IDs (first column: 'name')
                mod_df["name"].to_csv(f, index=False, header=False)
        
            module_args.append(str(mod_out))

        # ===============================
        # Run CAMI
        # ===============================

        cmd = [
            "/home/bbc8731/miniconda3/envs/cami/bin/python",
            "/home/bbc8731/cami/src/cami.py",
            "-n", str(ppi_tsv),
            "-o", str(run_dir),
            "--save_temps",
            "--external_results", *module_args,
            "--external_only",
            "--consensus",
            "--seeds", str(seeds_txt),
        ]

        # subprocess.run(cmd, check=True)
        proc = subprocess.run(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        
        print("\n===== CAMI STDOUT =====")
        print(proc.stdout)
        
        print("\n===== CAMI STDERR =====")
        print(proc.stderr)
        
        print("\nReturn code:", proc.returncode)
# Out:
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 29 seed genes CAMI (union) proposes 291 genes to add to the Active Module
# With the 29 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 29 seed genes CAMI (first_neighbours) proposes 3996 genes to add to the Active Module
# With the 29 seed genes CAMI (cami_v2_trustrank) proposes 59 genes to add to the Active Module
# With the 29 seed genes CAMI (cami_v3_trustrank) proposes 102 genes to add to the Active Module
# With the 29 seed genes the module predicted by no_tool contains 30 genes
# With the 29 seed genes the module predicted by robust contains 57 genes
# With the 29 seed genes the module predicted by robust_bias_aware contains 55 genes
# With the 29 seed genes the module predicted by diamond contains 230 genes
# With the 29 seed genes the module predicted by rwr contains 65 genes
# With the 29 seed genes the module predicted by domino contains 78 genes
# With the 29 seed genes the module predicted by union contains 320 genes
# With the 29 seed genes the module predicted by intersection contains 30 genes
# With the 29 seed genes the module predicted by first_neighbours contains 4008 genes
# With the 29 seed genes the module predicted by cami_v2_trustrank contains 88 genes
# With the 29 seed genes the module predicted by cami_v3_trustrank contains 131 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.amygdala/tmp/d2d8269e-c422-4c42-8179-3aecfd0fd04f
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.amygdala/tmp/d2d8269e-c422-4c42-8179-3aecfd0fd04f
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 31 seed genes CAMI (union) proposes 277 genes to add to the Active Module
# With the 31 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 31 seed genes CAMI (first_neighbours) proposes 4041 genes to add to the Active Module
# With the 31 seed genes CAMI (cami_v2_trustrank) proposes 56 genes to add to the Active Module
# With the 31 seed genes CAMI (cami_v3_trustrank) proposes 97 genes to add to the Active Module
# With the 31 seed genes the module predicted by no_tool contains 32 genes
# With the 31 seed genes the module predicted by robust contains 60 genes
# With the 31 seed genes the module predicted by robust_bias_aware contains 62 genes
# With the 31 seed genes the module predicted by diamond contains 232 genes
# With the 31 seed genes the module predicted by rwr contains 53 genes
# With the 31 seed genes the module predicted by domino contains 78 genes
# With the 31 seed genes the module predicted by union contains 308 genes
# With the 31 seed genes the module predicted by intersection contains 32 genes
# With the 31 seed genes the module predicted by first_neighbours contains 4054 genes
# With the 31 seed genes the module predicted by cami_v2_trustrank contains 87 genes
# With the 31 seed genes the module predicted by cami_v3_trustrank contains 128 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.brain/tmp/a500bd6c-fe11-44f2-a7e0-888aac7ff1f7
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.brain/tmp/a500bd6c-fe11-44f2-a7e0-888aac7ff1f7
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 30 seed genes CAMI (union) proposes 278 genes to add to the Active Module
# With the 30 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 30 seed genes CAMI (first_neighbours) proposes 4023 genes to add to the Active Module
# With the 30 seed genes CAMI (cami_v2_trustrank) proposes 56 genes to add to the Active Module
# With the 30 seed genes CAMI (cami_v3_trustrank) proposes 98 genes to add to the Active Module
# With the 30 seed genes the module predicted by no_tool contains 31 genes
# With the 30 seed genes the module predicted by robust contains 64 genes
# With the 30 seed genes the module predicted by robust_bias_aware contains 62 genes
# With the 30 seed genes the module predicted by diamond contains 231 genes
# With the 30 seed genes the module predicted by rwr contains 54 genes
# With the 30 seed genes the module predicted by domino contains 73 genes
# With the 30 seed genes the module predicted by union contains 308 genes
# With the 30 seed genes the module predicted by intersection contains 31 genes
# With the 30 seed genes the module predicted by first_neighbours contains 4036 genes
# With the 30 seed genes the module predicted by cami_v2_trustrank contains 86 genes
# With the 30 seed genes the module predicted by cami_v3_trustrank contains 128 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.dorsal_root_ganglia/tmp/4f8f1506-9c30-4140-a73c-545185f36482
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.dorsal_root_ganglia/tmp/4f8f1506-9c30-4140-a73c-545185f36482
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 31 seed genes CAMI (union) proposes 283 genes to add to the Active Module
# With the 31 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 31 seed genes CAMI (first_neighbours) proposes 4041 genes to add to the Active Module
# With the 31 seed genes CAMI (cami_v2_trustrank) proposes 57 genes to add to the Active Module
# With the 31 seed genes CAMI (cami_v3_trustrank) proposes 100 genes to add to the Active Module
# With the 31 seed genes the module predicted by no_tool contains 32 genes
# With the 31 seed genes the module predicted by robust_bias_aware contains 62 genes
# With the 31 seed genes the module predicted by robust contains 62 genes
# With the 31 seed genes the module predicted by diamond contains 232 genes
# With the 31 seed genes the module predicted by rwr contains 52 genes
# With the 31 seed genes the module predicted by domino contains 85 genes
# With the 31 seed genes the module predicted by union contains 314 genes
# With the 31 seed genes the module predicted by intersection contains 32 genes
# With the 31 seed genes the module predicted by first_neighbours contains 4054 genes
# With the 31 seed genes the module predicted by cami_v2_trustrank contains 88 genes
# With the 31 seed genes the module predicted by cami_v3_trustrank contains 131 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.hypothalamus/tmp/6a245c00-4587-408a-83fb-57983e33d363
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.hypothalamus/tmp/6a245c00-4587-408a-83fb-57983e33d363
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 29 seed genes CAMI (union) proposes 299 genes to add to the Active Module
# With the 29 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 29 seed genes CAMI (first_neighbours) proposes 3944 genes to add to the Active Module
# With the 29 seed genes CAMI (cami_v2_trustrank) proposes 60 genes to add to the Active Module
# With the 29 seed genes CAMI (cami_v3_trustrank) proposes 105 genes to add to the Active Module
# With the 29 seed genes the module predicted by no_tool contains 30 genes
# With the 29 seed genes the module predicted by robust contains 68 genes
# With the 29 seed genes the module predicted by robust_bias_aware contains 67 genes
# With the 29 seed genes the module predicted by diamond contains 230 genes
# With the 29 seed genes the module predicted by rwr contains 96 genes
# With the 29 seed genes the module predicted by domino contains 65 genes
# With the 29 seed genes the module predicted by union contains 328 genes
# With the 29 seed genes the module predicted by intersection contains 30 genes
# With the 29 seed genes the module predicted by first_neighbours contains 3957 genes
# With the 29 seed genes the module predicted by cami_v2_trustrank contains 89 genes
# With the 29 seed genes the module predicted by cami_v3_trustrank contains 134 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.salivary_gland/tmp/abf903a1-e371-450d-a465-84c7b00f8f45
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.salivary_gland/tmp/abf903a1-e371-450d-a465-84c7b00f8f45
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 41 seed genes CAMI (union) proposes 334 genes to add to the Active Module
# With the 41 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 41 seed genes CAMI (first_neighbours) proposes 4299 genes to add to the Active Module
# With the 41 seed genes CAMI (cami_v2_trustrank) proposes 67 genes to add to the Active Module
# With the 41 seed genes CAMI (cami_v3_trustrank) proposes 117 genes to add to the Active Module
# With the 41 seed genes the module predicted by no_tool contains 42 genes
# With the 41 seed genes the module predicted by robust contains 81 genes
# With the 41 seed genes the module predicted by robust_bias_aware contains 80 genes
# With the 41 seed genes the module predicted by diamond contains 242 genes
# With the 41 seed genes the module predicted by rwr contains 104 genes
# With the 41 seed genes the module predicted by domino contains 107 genes
# With the 41 seed genes the module predicted by union contains 375 genes
# With the 41 seed genes the module predicted by intersection contains 42 genes
# With the 41 seed genes the module predicted by first_neighbours contains 4315 genes
# With the 41 seed genes the module predicted by cami_v2_trustrank contains 108 genes
# With the 41 seed genes the module predicted by cami_v3_trustrank contains 158 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.uniprot_ppi/tmp/172b5363-ed7f-4287-83e1-5f4fe71d240a
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Assembly_and_Packaging.uniprot_ppi/tmp/172b5363-ed7f-4287-83e1-5f4fe71d240a
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 165 seed genes CAMI (union) proposes 657 genes to add to the Active Module
# With the 165 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 165 seed genes CAMI (first_neighbours) proposes 7817 genes to add to the Active Module
# With the 165 seed genes CAMI (cami_v2_trustrank) proposes 132 genes to add to the Active Module
# With the 165 seed genes CAMI (cami_v3_trustrank) proposes 230 genes to add to the Active Module
# With the 165 seed genes the module predicted by no_tool contains 166 genes
# With the 165 seed genes the module predicted by robust contains 304 genes
# With the 165 seed genes the module predicted by robust_bias_aware contains 307 genes
# With the 165 seed genes the module predicted by rwr contains 439 genes
# With the 165 seed genes the module predicted by diamond contains 366 genes
# With the 165 seed genes the module predicted by domino contains 362 genes
# With the 165 seed genes the module predicted by union contains 822 genes
# With the 165 seed genes the module predicted by intersection contains 165 genes
# With the 165 seed genes the module predicted by first_neighbours contains 7857 genes
# With the 165 seed genes the module predicted by cami_v2_trustrank contains 297 genes
# With the 165 seed genes the module predicted by cami_v3_trustrank contains 395 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.hypothalamus/tmp/5b460f45-9d0d-4d45-b1db-7137791aa34c
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.hypothalamus/tmp/5b460f45-9d0d-4d45-b1db-7137791aa34c
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 174 seed genes CAMI (union) proposes 624 genes to add to the Active Module
# With the 174 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 174 seed genes CAMI (first_neighbours) proposes 7953 genes to add to the Active Module
# With the 174 seed genes CAMI (cami_v2_trustrank) proposes 125 genes to add to the Active Module
# With the 174 seed genes CAMI (cami_v3_trustrank) proposes 219 genes to add to the Active Module
# With the 174 seed genes the module predicted by no_tool contains 175 genes
# With the 174 seed genes the module predicted by robust contains 324 genes
# With the 174 seed genes the module predicted by robust_bias_aware contains 325 genes
# With the 174 seed genes the module predicted by diamond contains 375 genes
# With the 174 seed genes the module predicted by rwr contains 430 genes
# With the 174 seed genes the module predicted by domino contains 367 genes
# With the 174 seed genes the module predicted by union contains 798 genes
# With the 174 seed genes the module predicted by intersection contains 175 genes
# With the 174 seed genes the module predicted by first_neighbours contains 7998 genes
# With the 174 seed genes the module predicted by cami_v2_trustrank contains 299 genes
# With the 174 seed genes the module predicted by cami_v3_trustrank contains 393 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.dorsal_root_ganglia/tmp/a8af5f0e-d0fc-474e-872d-8b765a592ba5
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.dorsal_root_ganglia/tmp/a8af5f0e-d0fc-474e-872d-8b765a592ba5
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 169 seed genes CAMI (union) proposes 622 genes to add to the Active Module
# With the 169 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 169 seed genes CAMI (first_neighbours) proposes 7875 genes to add to the Active Module
# With the 169 seed genes CAMI (cami_v2_trustrank) proposes 125 genes to add to the Active Module
# With the 169 seed genes CAMI (cami_v3_trustrank) proposes 218 genes to add to the Active Module
# With the 169 seed genes the module predicted by no_tool contains 170 genes
# With the 169 seed genes the module predicted by robust contains 332 genes
# With the 169 seed genes the module predicted by robust_bias_aware contains 327 genes
# With the 169 seed genes the module predicted by diamond contains 370 genes
# With the 169 seed genes the module predicted by rwr contains 446 genes
# With the 169 seed genes the module predicted by domino contains 325 genes
# With the 169 seed genes the module predicted by union contains 791 genes
# With the 169 seed genes the module predicted by intersection contains 169 genes
# With the 169 seed genes the module predicted by first_neighbours contains 7918 genes
# With the 169 seed genes the module predicted by cami_v2_trustrank contains 294 genes
# With the 169 seed genes the module predicted by cami_v3_trustrank contains 387 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.salivary_gland/tmp/c053ce28-5f6f-42c9-a4e3-3bf6670f1653
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.salivary_gland/tmp/c053ce28-5f6f-42c9-a4e3-3bf6670f1653
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 167 seed genes CAMI (union) proposes 571 genes to add to the Active Module
# With the 167 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 167 seed genes CAMI (first_neighbours) proposes 7850 genes to add to the Active Module
# With the 167 seed genes CAMI (cami_v2_trustrank) proposes 115 genes to add to the Active Module
# With the 167 seed genes CAMI (cami_v3_trustrank) proposes 200 genes to add to the Active Module
# With the 167 seed genes the module predicted by no_tool contains 168 genes
# With the 167 seed genes the module predicted by robust contains 313 genes
# With the 167 seed genes the module predicted by robust_bias_aware contains 314 genes
# With the 167 seed genes the module predicted by diamond contains 368 genes
# With the 167 seed genes the module predicted by rwr contains 420 genes
# With the 167 seed genes the module predicted by domino contains 296 genes
# With the 167 seed genes the module predicted by union contains 738 genes
# With the 167 seed genes the module predicted by intersection contains 167 genes
# With the 167 seed genes the module predicted by first_neighbours contains 7890 genes
# With the 167 seed genes the module predicted by cami_v2_trustrank contains 282 genes
# With the 167 seed genes the module predicted by cami_v3_trustrank contains 367 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.brain/tmp/99b8ca30-c401-445f-96e0-ac2db38a44e3
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.brain/tmp/99b8ca30-c401-445f-96e0-ac2db38a44e3
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 163 seed genes CAMI (union) proposes 563 genes to add to the Active Module
# With the 163 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 163 seed genes CAMI (first_neighbours) proposes 7830 genes to add to the Active Module
# With the 163 seed genes CAMI (cami_v2_trustrank) proposes 113 genes to add to the Active Module
# With the 163 seed genes CAMI (cami_v3_trustrank) proposes 198 genes to add to the Active Module
# With the 163 seed genes the module predicted by no_tool contains 164 genes
# With the 163 seed genes the module predicted by robust contains 307 genes
# With the 163 seed genes the module predicted by robust_bias_aware contains 306 genes
# With the 163 seed genes the module predicted by diamond contains 364 genes
# With the 163 seed genes the module predicted by rwr contains 382 genes
# With the 163 seed genes the module predicted by domino contains 302 genes
# With the 163 seed genes the module predicted by union contains 726 genes
# With the 163 seed genes the module predicted by intersection contains 163 genes
# With the 163 seed genes the module predicted by first_neighbours contains 7868 genes
# With the 163 seed genes the module predicted by cami_v2_trustrank contains 276 genes
# With the 163 seed genes the module predicted by cami_v3_trustrank contains 361 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.amygdala/tmp/29027dcc-fc48-412e-a5a8-4eab5f9106da
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.amygdala/tmp/29027dcc-fc48-412e-a5a8-4eab5f9106da
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 200 seed genes CAMI (union) proposes 778 genes to add to the Active Module
# With the 200 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 200 seed genes CAMI (first_neighbours) proposes 8185 genes to add to the Active Module
# With the 200 seed genes CAMI (cami_v2_trustrank) proposes 156 genes to add to the Active Module
# With the 200 seed genes CAMI (cami_v3_trustrank) proposes 273 genes to add to the Active Module
# With the 200 seed genes the module predicted by no_tool contains 200 genes
# With the 200 seed genes the module predicted by robust contains 386 genes
# With the 200 seed genes the module predicted by robust_bias_aware contains 383 genes
# With the 200 seed genes the module predicted by diamond contains 400 genes
# With the 200 seed genes the module predicted by rwr contains 616 genes
# With the 200 seed genes the module predicted by domino contains 403 genes
# With the 200 seed genes the module predicted by union contains 977 genes
# With the 200 seed genes the module predicted by intersection contains 199 genes
# With the 200 seed genes the module predicted by first_neighbours contains 8239 genes
# With the 200 seed genes the module predicted by cami_v2_trustrank contains 355 genes
# With the 200 seed genes the module predicted by cami_v3_trustrank contains 472 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.uniprot_ppi/tmp/ee1ad49c-8671-47c7-9adf-9dbceb694f27
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Egress_and_Envelopment.uniprot_ppi/tmp/ee1ad49c-8671-47c7-9adf-9dbceb694f27
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 50 seed genes CAMI (union) proposes 366 genes to add to the Active Module
# With the 50 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 50 seed genes CAMI (first_neighbours) proposes 2942 genes to add to the Active Module
# With the 50 seed genes CAMI (cami_v2_trustrank) proposes 74 genes to add to the Active Module
# With the 50 seed genes CAMI (cami_v3_trustrank) proposes 129 genes to add to the Active Module
# With the 50 seed genes the module predicted by no_tool contains 51 genes
# With the 50 seed genes the module predicted by robust_bias_aware contains 192 genes
# With the 50 seed genes the module predicted by robust contains 192 genes
# With the 50 seed genes the module predicted by diamond contains 251 genes
# With the 50 seed genes the module predicted by rwr contains 140 genes
# With the 50 seed genes the module predicted by domino contains 50 genes
# With the 50 seed genes the module predicted by union contains 416 genes
# With the 50 seed genes the module predicted by intersection contains 50 genes
# With the 50 seed genes the module predicted by first_neighbours contains 2982 genes
# With the 50 seed genes the module predicted by cami_v2_trustrank contains 124 genes
# With the 50 seed genes the module predicted by cami_v3_trustrank contains 179 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.hypothalamus/tmp/3e7b6f18-8a99-4d65-9951-048fa429d610
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.hypothalamus/tmp/3e7b6f18-8a99-4d65-9951-048fa429d610
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 49 seed genes CAMI (union) proposes 357 genes to add to the Active Module
# With the 49 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 49 seed genes CAMI (first_neighbours) proposes 2885 genes to add to the Active Module
# With the 49 seed genes CAMI (cami_v2_trustrank) proposes 72 genes to add to the Active Module
# With the 49 seed genes CAMI (cami_v3_trustrank) proposes 125 genes to add to the Active Module
# With the 49 seed genes the module predicted by no_tool contains 50 genes
# With the 49 seed genes the module predicted by robust contains 183 genes
# With the 49 seed genes the module predicted by robust_bias_aware contains 184 genes
# With the 49 seed genes the module predicted by diamond contains 250 genes
# With the 49 seed genes the module predicted by rwr contains 138 genes
# With the 49 seed genes the module predicted by domino contains 49 genes
# With the 49 seed genes the module predicted by union contains 406 genes
# With the 49 seed genes the module predicted by intersection contains 49 genes
# With the 49 seed genes the module predicted by first_neighbours contains 2924 genes
# With the 49 seed genes the module predicted by cami_v2_trustrank contains 121 genes
# With the 49 seed genes the module predicted by cami_v3_trustrank contains 174 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.amygdala/tmp/9b0e0e48-454c-4ca2-b660-e6ff97759d47
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.amygdala/tmp/9b0e0e48-454c-4ca2-b660-e6ff97759d47
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 46 seed genes CAMI (union) proposes 389 genes to add to the Active Module
# With the 46 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 46 seed genes CAMI (first_neighbours) proposes 2990 genes to add to the Active Module
# With the 46 seed genes CAMI (cami_v2_trustrank) proposes 78 genes to add to the Active Module
# With the 46 seed genes CAMI (cami_v3_trustrank) proposes 137 genes to add to the Active Module
# With the 46 seed genes the module predicted by no_tool contains 47 genes
# With the 46 seed genes the module predicted by robust_bias_aware contains 195 genes
# With the 46 seed genes the module predicted by robust contains 202 genes
# With the 46 seed genes the module predicted by diamond contains 247 genes
# With the 46 seed genes the module predicted by rwr contains 119 genes
# With the 46 seed genes the module predicted by domino contains 68 genes
# With the 46 seed genes the module predicted by union contains 435 genes
# With the 46 seed genes the module predicted by intersection contains 46 genes
# With the 46 seed genes the module predicted by first_neighbours contains 3028 genes
# With the 46 seed genes the module predicted by cami_v2_trustrank contains 124 genes
# With the 46 seed genes the module predicted by cami_v3_trustrank contains 183 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.salivary_gland/tmp/7b573414-a079-49cf-8a1a-1f71db89e967
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.salivary_gland/tmp/7b573414-a079-49cf-8a1a-1f71db89e967
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 52 seed genes CAMI (union) proposes 384 genes to add to the Active Module
# With the 52 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 52 seed genes CAMI (first_neighbours) proposes 3006 genes to add to the Active Module
# With the 52 seed genes CAMI (cami_v2_trustrank) proposes 77 genes to add to the Active Module
# With the 52 seed genes CAMI (cami_v3_trustrank) proposes 135 genes to add to the Active Module
# With the 52 seed genes the module predicted by no_tool contains 53 genes
# With the 52 seed genes the module predicted by robust contains 217 genes
# With the 52 seed genes the module predicted by robust_bias_aware contains 206 genes
# With the 52 seed genes the module predicted by diamond contains 253 genes
# With the 52 seed genes the module predicted by rwr contains 143 genes
# With the 52 seed genes the module predicted by domino contains 56 genes
# With the 52 seed genes the module predicted by union contains 436 genes
# With the 52 seed genes the module predicted by intersection contains 52 genes
# With the 52 seed genes the module predicted by first_neighbours contains 3048 genes
# With the 52 seed genes the module predicted by cami_v2_trustrank contains 129 genes
# With the 52 seed genes the module predicted by cami_v3_trustrank contains 187 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.brain/tmp/12f38e6c-74d7-4df6-a889-8d2495153642
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.brain/tmp/12f38e6c-74d7-4df6-a889-8d2495153642
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 51 seed genes CAMI (union) proposes 398 genes to add to the Active Module
# With the 51 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 51 seed genes CAMI (first_neighbours) proposes 3090 genes to add to the Active Module
# With the 51 seed genes CAMI (cami_v2_trustrank) proposes 80 genes to add to the Active Module
# With the 51 seed genes CAMI (cami_v3_trustrank) proposes 140 genes to add to the Active Module
# With the 51 seed genes the module predicted by no_tool contains 52 genes
# With the 51 seed genes the module predicted by robust contains 200 genes
# With the 51 seed genes the module predicted by diamond contains 252 genes
# With the 51 seed genes the module predicted by robust_bias_aware contains 197 genes
# With the 51 seed genes the module predicted by rwr contains 141 genes
# With the 51 seed genes the module predicted by domino contains 67 genes
# With the 51 seed genes the module predicted by union contains 449 genes
# With the 51 seed genes the module predicted by intersection contains 51 genes
# With the 51 seed genes the module predicted by first_neighbours contains 3130 genes
# With the 51 seed genes the module predicted by cami_v2_trustrank contains 131 genes
# With the 51 seed genes the module predicted by cami_v3_trustrank contains 191 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.dorsal_root_ganglia/tmp/2b594f8d-c045-42d5-ab58-27aa9fda7cf5
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.dorsal_root_ganglia/tmp/2b594f8d-c045-42d5-ab58-27aa9fda7cf5
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 59 seed genes CAMI (union) proposes 505 genes to add to the Active Module
# With the 59 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 59 seed genes CAMI (first_neighbours) proposes 3295 genes to add to the Active Module
# With the 59 seed genes CAMI (cami_v2_trustrank) proposes 101 genes to add to the Active Module
# With the 59 seed genes CAMI (cami_v3_trustrank) proposes 177 genes to add to the Active Module
# With the 59 seed genes the module predicted by no_tool contains 60 genes
# With the 59 seed genes the module predicted by robust contains 223 genes
# With the 59 seed genes the module predicted by diamond contains 260 genes
# With the 59 seed genes the module predicted by robust_bias_aware contains 223 genes
# With the 59 seed genes the module predicted by rwr contains 284 genes
# With the 59 seed genes the module predicted by domino contains 93 genes
# With the 59 seed genes the module predicted by union contains 564 genes
# With the 59 seed genes the module predicted by intersection contains 59 genes
# With the 59 seed genes the module predicted by first_neighbours contains 3341 genes
# With the 59 seed genes the module predicted by cami_v2_trustrank contains 160 genes
# With the 59 seed genes the module predicted by cami_v3_trustrank contains 236 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.uniprot_ppi/tmp/33110b2a-a63b-4e84-9f9d-4e569439b7b2
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Entry_and_Uncoating.uniprot_ppi/tmp/33110b2a-a63b-4e84-9f9d-4e569439b7b2
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 90 seed genes CAMI (union) proposes 392 genes to add to the Active Module
# With the 90 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 90 seed genes CAMI (first_neighbours) proposes 5498 genes to add to the Active Module
# With the 90 seed genes CAMI (cami_v2_trustrank) proposes 79 genes to add to the Active Module
# With the 90 seed genes CAMI (cami_v3_trustrank) proposes 138 genes to add to the Active Module
# With the 90 seed genes the module predicted by no_tool contains 85 genes
# With the 90 seed genes the module predicted by robust_bias_aware contains 135 genes
# With the 90 seed genes the module predicted by robust contains 132 genes
# With the 90 seed genes the module predicted by rwr contains 226 genes
# With the 90 seed genes the module predicted by diamond contains 285 genes
# With the 90 seed genes the module predicted by domino contains 191 genes
# With the 90 seed genes the module predicted by union contains 476 genes
# With the 90 seed genes the module predicted by intersection contains 85 genes
# With the 90 seed genes the module predicted by first_neighbours contains 5513 genes
# With the 90 seed genes the module predicted by cami_v2_trustrank contains 163 genes
# With the 90 seed genes the module predicted by cami_v3_trustrank contains 222 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.dorsal_root_ganglia/tmp/d4be1183-d69a-4d9b-9057-c69e4ecc518e
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.dorsal_root_ganglia/tmp/d4be1183-d69a-4d9b-9057-c69e4ecc518e
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 88 seed genes CAMI (union) proposes 457 genes to add to the Active Module
# With the 88 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 88 seed genes CAMI (first_neighbours) proposes 5479 genes to add to the Active Module
# With the 88 seed genes CAMI (cami_v2_trustrank) proposes 92 genes to add to the Active Module
# With the 88 seed genes CAMI (cami_v3_trustrank) proposes 160 genes to add to the Active Module
# With the 88 seed genes the module predicted by no_tool contains 83 genes
# With the 88 seed genes the module predicted by robust contains 133 genes
# With the 88 seed genes the module predicted by robust_bias_aware contains 132 genes
# With the 88 seed genes the module predicted by diamond contains 283 genes
# With the 88 seed genes the module predicted by rwr contains 243 genes
# With the 88 seed genes the module predicted by domino contains 240 genes
# With the 88 seed genes the module predicted by union contains 539 genes
# With the 88 seed genes the module predicted by intersection contains 82 genes
# With the 88 seed genes the module predicted by first_neighbours contains 5493 genes
# With the 88 seed genes the module predicted by cami_v2_trustrank contains 174 genes
# With the 88 seed genes the module predicted by cami_v3_trustrank contains 242 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.amygdala/tmp/f4c23b4f-db31-4fed-b91e-8c851ca914ad
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.amygdala/tmp/f4c23b4f-db31-4fed-b91e-8c851ca914ad
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 143 seed genes CAMI (union) proposes 572 genes to add to the Active Module
# With the 143 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 143 seed genes CAMI (first_neighbours) proposes 5783 genes to add to the Active Module
# With the 143 seed genes CAMI (cami_v2_trustrank) proposes 115 genes to add to the Active Module
# With the 143 seed genes CAMI (cami_v3_trustrank) proposes 201 genes to add to the Active Module
# With the 143 seed genes the module predicted by no_tool contains 112 genes
# With the 143 seed genes the module predicted by robust contains 202 genes
# With the 143 seed genes the module predicted by robust_bias_aware contains 202 genes
# With the 143 seed genes the module predicted by diamond contains 312 genes
# With the 143 seed genes the module predicted by rwr contains 320 genes
# With the 143 seed genes the module predicted by domino contains 337 genes
# With the 143 seed genes the module predicted by union contains 683 genes
# With the 143 seed genes the module predicted by intersection contains 112 genes
# With the 143 seed genes the module predicted by first_neighbours contains 5803 genes
# With the 143 seed genes the module predicted by cami_v2_trustrank contains 226 genes
# With the 143 seed genes the module predicted by cami_v3_trustrank contains 312 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.uniprot_ppi/tmp/547215d6-2a9f-4890-9735-6074d8d0a3fe
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.uniprot_ppi/tmp/547215d6-2a9f-4890-9735-6074d8d0a3fe
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 92 seed genes CAMI (union) proposes 455 genes to add to the Active Module
# With the 92 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 92 seed genes CAMI (first_neighbours) proposes 5064 genes to add to the Active Module
# With the 92 seed genes CAMI (cami_v2_trustrank) proposes 91 genes to add to the Active Module
# With the 92 seed genes CAMI (cami_v3_trustrank) proposes 160 genes to add to the Active Module
# With the 92 seed genes the module predicted by no_tool contains 83 genes
# With the 92 seed genes the module predicted by robust contains 132 genes
# With the 92 seed genes the module predicted by robust_bias_aware contains 134 genes
# With the 92 seed genes the module predicted by diamond contains 283 genes
# With the 92 seed genes the module predicted by rwr contains 245 genes
# With the 92 seed genes the module predicted by domino contains 240 genes
# With the 92 seed genes the module predicted by union contains 537 genes
# With the 92 seed genes the module predicted by intersection contains 83 genes
# With the 92 seed genes the module predicted by first_neighbours contains 5079 genes
# With the 92 seed genes the module predicted by cami_v2_trustrank contains 173 genes
# With the 92 seed genes the module predicted by cami_v3_trustrank contains 242 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.brain/tmp/9a55859a-4133-475a-83d9-ddd5fea78975
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.brain/tmp/9a55859a-4133-475a-83d9-ddd5fea78975
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 87 seed genes CAMI (union) proposes 443 genes to add to the Active Module
# With the 87 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 87 seed genes CAMI (first_neighbours) proposes 5051 genes to add to the Active Module
# With the 87 seed genes CAMI (cami_v2_trustrank) proposes 89 genes to add to the Active Module
# With the 87 seed genes CAMI (cami_v3_trustrank) proposes 156 genes to add to the Active Module
# With the 87 seed genes the module predicted by no_tool contains 82 genes
# With the 87 seed genes the module predicted by robust contains 131 genes
# With the 87 seed genes the module predicted by robust_bias_aware contains 133 genes
# With the 87 seed genes the module predicted by diamond contains 282 genes
# With the 87 seed genes the module predicted by rwr contains 230 genes
# With the 87 seed genes the module predicted by domino contains 234 genes
# With the 87 seed genes the module predicted by union contains 524 genes
# With the 87 seed genes the module predicted by intersection contains 82 genes
# With the 87 seed genes the module predicted by first_neighbours contains 5067 genes
# With the 87 seed genes the module predicted by cami_v2_trustrank contains 170 genes
# With the 87 seed genes the module predicted by cami_v3_trustrank contains 237 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.hypothalamus/tmp/2ba1fa87-798e-44d9-9988-15c15604f5c7
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Immune_Evasion.hypothalamus/tmp/2ba1fa87-798e-44d9-9988-15c15604f5c7
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 104 seed genes CAMI (union) proposes 393 genes to add to the Active Module
# With the 104 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 104 seed genes CAMI (first_neighbours) proposes 5570 genes to add to the Active Module
# With the 104 seed genes CAMI (cami_v2_trustrank) proposes 79 genes to add to the Active Module
# With the 104 seed genes CAMI (cami_v3_trustrank) proposes 138 genes to add to the Active Module
# With the 104 seed genes the module predicted by no_tool contains 86 genes
# With the 104 seed genes the module predicted by robust contains 133 genes
# With the 104 seed genes the module predicted by robust_bias_aware contains 133 genes
# With the 104 seed genes the module predicted by diamond contains 286 genes
# With the 104 seed genes the module predicted by rwr contains 243 genes
# With the 104 seed genes the module predicted by domino contains 179 genes
# With the 104 seed genes the module predicted by union contains 478 genes
# With the 104 seed genes the module predicted by intersection contains 86 genes
# With the 104 seed genes the module predicted by first_neighbours contains 5584 genes
# With the 104 seed genes the module predicted by cami_v2_trustrank contains 164 genes
# With the 104 seed genes the module predicted by cami_v3_trustrank contains 223 genes
# ...
# With the 44 seed genes CAMI (cami_v2_trustrank) proposes 56 genes to add to the Active Module
# With the 44 seed genes CAMI (cami_v3_trustrank) proposes 98 genes to add to the Active Module
# With the 44 seed genes the module predicted by no_tool contains 45 genes
# With the 44 seed genes the module predicted by diamond contains 245 genes
# With the 44 seed genes the module predicted by robust contains 96 genes
# With the 44 seed genes the module predicted by robust_bias_aware contains 93 genes
# With the 44 seed genes the module predicted by rwr contains 78 genes
# With the 44 seed genes the module predicted by domino contains 71 genes
# With the 44 seed genes the module predicted by union contains 323 genes
# With the 44 seed genes the module predicted by intersection contains 44 genes
# With the 44 seed genes the module predicted by first_neighbours contains 3818 genes
# With the 44 seed genes the module predicted by cami_v2_trustrank contains 100 genes
# With the 44 seed genes the module predicted by cami_v3_trustrank contains 142 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Virion_Components.dorsal_root_ganglia/tmp/45c6d1fe-824d-4062-8037-c137dfa2bdae
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Virion_Components.dorsal_root_ganglia/tmp/45c6d1fe-824d-4062-8037-c137dfa2bdae
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 46 seed genes CAMI (union) proposes 289 genes to add to the Active Module
# With the 46 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 46 seed genes CAMI (first_neighbours) proposes 3813 genes to add to the Active Module
# With the 46 seed genes CAMI (cami_v2_trustrank) proposes 58 genes to add to the Active Module
# With the 46 seed genes CAMI (cami_v3_trustrank) proposes 102 genes to add to the Active Module
# With the 46 seed genes the module predicted by no_tool contains 47 genes
# With the 46 seed genes the module predicted by robust_bias_aware contains 101 genes
# With the 46 seed genes the module predicted by robust contains 99 genes
# With the 46 seed genes the module predicted by diamond contains 247 genes
# With the 46 seed genes the module predicted by rwr contains 89 genes
# With the 46 seed genes the module predicted by domino contains 78 genes
# With the 46 seed genes the module predicted by union contains 335 genes
# With the 46 seed genes the module predicted by intersection contains 46 genes
# With the 46 seed genes the module predicted by first_neighbours contains 3829 genes
# With the 46 seed genes the module predicted by cami_v2_trustrank contains 104 genes
# With the 46 seed genes the module predicted by cami_v3_trustrank contains 148 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Virion_Components.hypothalamus/tmp/9aa2f5d1-e079-40a1-8489-d9f3ca9e440e
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/Virion_Components.hypothalamus/tmp/9aa2f5d1-e079-40a1-8489-d9f3ca9e440e
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 408 seed genes CAMI (union) proposes 720 genes to add to the Active Module
# With the 408 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 408 seed genes CAMI (first_neighbours) proposes 10854 genes to add to the Active Module
# With the 408 seed genes CAMI (cami_v2_trustrank) proposes 144 genes to add to the Active Module
# With the 408 seed genes CAMI (cami_v3_trustrank) proposes 252 genes to add to the Active Module
# With the 408 seed genes the module predicted by no_tool contains 403 genes
# With the 408 seed genes the module predicted by robust contains 592 genes
# With the 408 seed genes the module predicted by robust_bias_aware contains 592 genes
# With the 408 seed genes the module predicted by rwr contains 760 genes
# With the 408 seed genes the module predicted by diamond contains 603 genes
# With the 408 seed genes the module predicted by domino contains 564 genes
# With the 408 seed genes the module predicted by union contains 1122 genes
# With the 408 seed genes the module predicted by intersection contains 402 genes
# With the 408 seed genes the module predicted by first_neighbours contains 10894 genes
# With the 408 seed genes the module predicted by cami_v2_trustrank contains 546 genes
# With the 408 seed genes the module predicted by cami_v3_trustrank contains 654 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.amygdala/tmp/66fafadb-bcdd-402b-a864-2016a53d27bc
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.amygdala/tmp/66fafadb-bcdd-402b-a864-2016a53d27bc
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 411 seed genes CAMI (union) proposes 865 genes to add to the Active Module
# With the 411 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 411 seed genes CAMI (first_neighbours) proposes 10787 genes to add to the Active Module
# With the 411 seed genes CAMI (cami_v2_trustrank) proposes 173 genes to add to the Active Module
# With the 411 seed genes CAMI (cami_v3_trustrank) proposes 303 genes to add to the Active Module
# With the 411 seed genes the module predicted by no_tool contains 406 genes
# With the 411 seed genes the module predicted by robust contains 581 genes
# With the 411 seed genes the module predicted by robust_bias_aware contains 583 genes
# With the 411 seed genes the module predicted by diamond contains 606 genes
# With the 411 seed genes the module predicted by rwr contains 758 genes
# With the 411 seed genes the module predicted by domino contains 736 genes
# With the 411 seed genes the module predicted by union contains 1270 genes
# With the 411 seed genes the module predicted by intersection contains 405 genes
# With the 411 seed genes the module predicted by first_neighbours contains 10829 genes
# With the 411 seed genes the module predicted by cami_v2_trustrank contains 578 genes
# With the 411 seed genes the module predicted by cami_v3_trustrank contains 708 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.hypothalamus/tmp/b22ca5a4-d2ed-4185-87fe-1972899cc407
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.hypothalamus/tmp/b22ca5a4-d2ed-4185-87fe-1972899cc407
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 420 seed genes CAMI (union) proposes 789 genes to add to the Active Module
# With the 420 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 420 seed genes CAMI (first_neighbours) proposes 10901 genes to add to the Active Module
# With the 420 seed genes CAMI (cami_v2_trustrank) proposes 158 genes to add to the Active Module
# With the 420 seed genes CAMI (cami_v3_trustrank) proposes 277 genes to add to the Active Module
# With the 420 seed genes the module predicted by no_tool contains 415 genes
# With the 420 seed genes the module predicted by robust contains 595 genes
# With the 420 seed genes the module predicted by robust_bias_aware contains 593 genes
# With the 420 seed genes the module predicted by diamond contains 615 genes
# With the 420 seed genes the module predicted by rwr contains 787 genes
# With the 420 seed genes the module predicted by domino contains 646 genes
# With the 420 seed genes the module predicted by union contains 1203 genes
# With the 420 seed genes the module predicted by intersection contains 414 genes
# With the 420 seed genes the module predicted by first_neighbours contains 10945 genes
# With the 420 seed genes the module predicted by cami_v2_trustrank contains 572 genes
# With the 420 seed genes the module predicted by cami_v3_trustrank contains 691 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.dorsal_root_ganglia/tmp/5007bd0e-bdb8-472e-a44d-47bdd9710514
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.dorsal_root_ganglia/tmp/5007bd0e-bdb8-472e-a44d-47bdd9710514
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 431 seed genes CAMI (union) proposes 912 genes to add to the Active Module
# With the 431 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 431 seed genes CAMI (first_neighbours) proposes 10886 genes to add to the Active Module
# With the 431 seed genes CAMI (cami_v2_trustrank) proposes 183 genes to add to the Active Module
# With the 431 seed genes CAMI (cami_v3_trustrank) proposes 320 genes to add to the Active Module
# With the 431 seed genes the module predicted by no_tool contains 413 genes
# With the 431 seed genes the module predicted by robust_bias_aware contains 588 genes
# With the 431 seed genes the module predicted by robust contains 589 genes
# With the 431 seed genes the module predicted by diamond contains 613 genes
# With the 431 seed genes the module predicted by rwr contains 844 genes
# With the 431 seed genes the module predicted by domino contains 727 genes
# With the 431 seed genes the module predicted by union contains 1324 genes
# With the 431 seed genes the module predicted by intersection contains 412 genes
# With the 431 seed genes the module predicted by first_neighbours contains 10929 genes
# With the 431 seed genes the module predicted by cami_v2_trustrank contains 595 genes
# With the 431 seed genes the module predicted by cami_v3_trustrank contains 732 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.salivary_gland/tmp/297b8136-e2da-4596-97ae-bb572532df3e
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.salivary_gland/tmp/297b8136-e2da-4596-97ae-bb572532df3e
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 421 seed genes CAMI (union) proposes 772 genes to add to the Active Module
# With the 421 seed genes CAMI (intersection) proposes 0 genes to add to the Active Module
# With the 421 seed genes CAMI (first_neighbours) proposes 10824 genes to add to the Active Module
# With the 421 seed genes CAMI (cami_v2_trustrank) proposes 155 genes to add to the Active Module
# With the 421 seed genes CAMI (cami_v3_trustrank) proposes 271 genes to add to the Active Module
# With the 421 seed genes the module predicted by no_tool contains 412 genes
# With the 421 seed genes the module predicted by robust_bias_aware contains 596 genes
# With the 421 seed genes the module predicted by robust contains 594 genes
# With the 421 seed genes the module predicted by diamond contains 612 genes
# With the 421 seed genes the module predicted by rwr contains 747 genes
# With the 421 seed genes the module predicted by domino contains 642 genes
# With the 421 seed genes the module predicted by union contains 1183 genes
# With the 421 seed genes the module predicted by intersection contains 411 genes
# With the 421 seed genes the module predicted by first_neighbours contains 10867 genes
# With the 421 seed genes the module predicted by cami_v2_trustrank contains 566 genes
# With the 421 seed genes the module predicted by cami_v3_trustrank contains 682 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.brain/tmp/30c85cc0-e5fd-4313-9d1c-863c3be61c3d
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.brain/tmp/30c85cc0-e5fd-4313-9d1c-863c3be61c3d
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
#
# ===== CAMI STDOUT =====
# CAMI started
# Creating the PPI network graph and seed list...
# With the 534 seed genes CAMI (union) proposes 1130 genes to add to the Active Module
# With the 534 seed genes CAMI (intersection) proposes 1 genes to add to the Active Module
# With the 534 seed genes CAMI (first_neighbours) proposes 11311 genes to add to the Active Module
# With the 534 seed genes CAMI (cami_v2_trustrank) proposes 226 genes to add to the Active Module
# With the 534 seed genes CAMI (cami_v3_trustrank) proposes 396 genes to add to the Active Module
# With the 534 seed genes the module predicted by no_tool contains 502 genes
# With the 534 seed genes the module predicted by robust contains 705 genes
# With the 534 seed genes the module predicted by robust_bias_aware contains 703 genes
# With the 534 seed genes the module predicted by diamond contains 702 genes
# With the 534 seed genes the module predicted by rwr contains 1040 genes
# With the 534 seed genes the module predicted by domino contains 918 genes
# With the 534 seed genes the module predicted by union contains 1631 genes
# With the 534 seed genes the module predicted by intersection contains 502 genes
# With the 534 seed genes the module predicted by first_neighbours contains 11366 genes
# With the 534 seed genes the module predicted by cami_v2_trustrank contains 727 genes
# With the 534 seed genes the module predicted by cami_v3_trustrank contains 897 genes
# All temporary files were kept in /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.uniprot_ppi/tmp/dfb56af1-a04c-469e-8595-664bc1688c9b
# You can remove them by typing: rm -rv /home/bbc8731/HSV/4_consensus_module_detection/cami_results/CC_background_control.uniprot_ppi/tmp/dfb56af1-a04c-469e-8595-664bc1688c9b
# Please note that CAMI internally works with the indices of the vertices in the PPI-Network. This means that the names in the inputfiles of the tools do not correspond to the gene names but to their indices in the graph_tool Graph that CAMI creates.
#
#
# ===== CAMI STDERR =====
#
#
# Return code: 0
