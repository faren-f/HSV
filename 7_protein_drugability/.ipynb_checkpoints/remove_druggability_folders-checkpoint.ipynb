# %%
import glob
from pathlib import Path
import shutil

# %%
path = Path("/home/bbc8731/HSV/3_module_expansion/data/categories_methods/")
dirs = list(path.rglob("drugability"))
for d in dirs:
    print(d)
# Out:
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Assembly_and_Packaging/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Egress_and_Envelopment/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Entry_and_Uncoating/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Immune_Evasion/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Replication_and_Transcription/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/BP_Uncharacterized/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/CC_Host_Cytoplasm/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/CC_Host_Membrane/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/CC_Host_Nucleus/drugability
# /home/bbc8731/HSV/3_module_expansion/data/categories_methods/CC_Virion_Components/drugability

# %%
for d in path.rglob("drugability"):
    if d.is_dir():
        shutil.rmtree(d)
