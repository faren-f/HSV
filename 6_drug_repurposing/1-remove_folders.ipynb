# %%
import glob
from pathlib import Path
import shutil

# %%
path = Path("/home/bbc8731/HSV/3_module_expansion/data/categories_methods/")
dirs = list(path.rglob("drug_repurposing"))
for d in dirs:
    print(d)

# %%
for d in path.rglob("drug_repurposing"):
    if d.is_dir():
        shutil.rmtree(d)
